# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('job-market(1).csv')

# %%
data.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores  2018-10-07T00:00:00.000Z
# 1                                     Aldi Stores  2018-10-07T00:00:00.000Z
# ...

# %%
data.dtypes
# Out:
# Id                   float64
# Title                 object
# Company               object
# Date                  object
# Location              object
# Area                  object
# Classification        object
# SubClassification     object
# Requirement           object
# FullDescription       object
# LowestSalary         float64
# HighestSalary        float64
# JobType               object
# dtype: object

# %%
data['Date'] = pd.DatetimeIndex(data['Date'])

# %%
data.dtypes
# Out:
# Id                               float64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                          object
# Area                              object
# Classification                    object
# SubClassification                 object
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
data['Location'] = data['Location'].astype('category')
data['Area'] = data['Area'].astype('category')
data['Classification'] = data['Classification'].astype('category')
data['SubClassification'] = data['SubClassification'].astype('category')

# %%
data.dtypes
# Out:
# Id                               float64
# Title                             object
# Company                           object
# Date                 datetime64[ns, UTC]
# Location                        category
# Area                            category
# Classification                  category
# SubClassification               category
# Requirement                       object
# FullDescription                   object
# LowestSalary                     float64
# HighestSalary                    float64
# JobType                           object
# dtype: object

# %%
# Average Salary

data.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores 2018-10-07 00:00:00+00:00
# 1                                     Aldi Stores 2018-10-07 00:00:00+00:00
# ...

# %%
data.tail(10)
# Out:
#        Id Title Company Date Location Area Classification SubClassification  \
# 40779 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40780 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40781 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40782 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40783 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40784 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40785 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40786 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40787 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
# 40788 NaN   NaN     NaN  NaT      NaN  NaN            NaN               NaN
#
#       Requirement FullDescription  LowestSalary  HighestSalary JobType  \
# ...

# %%
data['Average_Salary'] = (data['HighestSalary'] + data['LowestSalary'])/2

# %%
data.head(10)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
# 3  37404330.0                              Team member - Belrose
# 4  37404308.0  Business Banking Contact Centre Specialist, Ni...
# 5  37404307.0  Business Banking Contact Centre Specialist, Ni...
# 6  37404355.0               Casual Café All-rounder in Semaphore
# 7  37404350.0           Casual Café All-rounder in Woolloongabba
# 8  37404301.0                                       Telemarketer
# 9  37404286.0                       Casual Dish Hand in Brighton
#
#                                           Company                      Date  \
# 0                                     Aldi Stores 2018-10-07 00:00:00+00:00
# 1                                     Aldi Stores 2018-10-07 00:00:00+00:00
# ...
